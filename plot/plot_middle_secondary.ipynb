# %% [markdown]
# {'uz': [0.004700587593000333, 0.004776369426527698]}
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00010919570922851562
# The size of the query result:  2
# Direct block read. generate select array. Time elapsed:  7.62939453125e-06
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  2.695469617843628
# get mass read for uz. Time elapsed:  1.14555025100708
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4456532001495361
# uz 199625024
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  1.9119830131530762
# get mass read for ux. Time elapsed:  1.1433207988739014
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4408924579620361
# ux 199625024
# apply secondary slice select array. Time elapsed:  2.1457672119140625e-06
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004776369426527698
# calculate particle level select array. Time elapsed:  0.5412576198577881
# apply particle level select array. Time elapsed:  0.05584096908569336
# selected data length:  53981
# Total Time elapsed:  10.456650972366333
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00022077560424804688
# The size of the query result:  2
# Direct block read. generate select array. Time elapsed:  0.10253763198852539
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  1.960353136062622
# get mass read for uz. Time elapsed:  1.1489691734313965
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4305751323699951
# uz 199625024
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  1.860863447189331
# get mass read for ux. Time elapsed:  1.1427545547485352
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4303553104400635
# ux 199625024
# apply secondary slice select array. Time elapsed:  0.2516169548034668
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004776369426527698
# calculate particle level select array. Time elapsed:  0.054167985916137695
# apply particle level select array. Time elapsed:  0.004055500030517578
# selected data length:  53981
# Total Time elapsed:  9.420764207839966
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00020074844360351562
# The size of the query result:  2
# sort block metadata by block start. Time elapsed:  1.9073486328125e-05
# find optimal read solution. Time elapsed:  2.002716064453125e-05
# generate select array. Time elapsed:  0.1774306297302246
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  1.8961350917816162
# get mass read for uz. Time elapsed:  1.1438894271850586
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4255485534667969
# uz 199625024
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  1.860661506652832
# get mass read for ux. Time elapsed:  1.1461105346679688
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4215021133422852
# ux 199625024
# apply secondary slice select array. Time elapsed:  1.4433338642120361
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004776369426527698
# calculate particle level select array. Time elapsed:  0.5337018966674805
# apply particle level select array. Time elapsed:  0.053180694580078125
# selected data length:  53981
# Total Time elapsed:  11.178446769714355
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00016260147094726562
# The size of the query result:  2
# sort block metadata by block start. Time elapsed:  1.9788742065429688e-05
# find optimal read solution. Time elapsed:  1.8596649169921875e-05
# generate select array. Time elapsed:  0.1042482852935791
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  1.8065223693847656
# get mass read for uz. Time elapsed:  1.1479766368865967
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4268808364868164
# uz 199625024
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  1.8606188297271729
# get mass read for ux. Time elapsed:  1.1412420272827148
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.4209554195404053
# ux 199625024
# apply secondary slice select array. Time elapsed:  0.254685640335083
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004776369426527698
# calculate particle level select array. Time elapsed:  0.045511484146118164
# apply particle level select array. Time elapsed:  0.005143404006958008
# selected data length:  53981
# Total Time elapsed:  9.241832971572876
# 53981

# %% [markdown]
# query index: Time elapsed:  9.989738464355469e-05
# The size of the query result:  1
# Direct block read. generate select array. Time elapsed:  5.7220458984375e-06
# size of self.read_chunk_range:  1
# read data from disk: uz
# get target data: uz. Time elapsed:  1.6493170261383057
# get mass read for uz. Time elapsed:  0.7046279907226562
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  0.8737895488739014
# uz 122471622
# size of self.read_chunk_range:  1
# read data from disk: ux
# get target data: ux. Time elapsed:  1.1342082023620605
# get mass read for ux. Time elapsed:  0.7107119560241699
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  0.8691656589508057
# ux 122471622
# apply secondary slice select array. Time elapsed:  2.1457672119140625e-06
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.00471654166321662
# calculate particle level select array. Time elapsed:  0.3334486484527588
# apply particle level select array. Time elapsed:  0.03148674964904785
# selected data length:  2344
# Total Time elapsed:  6.3526880741119385
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00019311904907226562
# The size of the query result:  1
# Direct block read. generate select array. Time elapsed:  0.05955982208251953
# size of self.read_chunk_range:  1
# read data from disk: uz
# get target data: uz. Time elapsed:  1.2647013664245605
# get mass read for uz. Time elapsed:  0.7081582546234131
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  0.8777387142181396
# uz 122471622
# size of self.read_chunk_range:  1
# read data from disk: ux
# get target data: ux. Time elapsed:  1.2551069259643555
# get mass read for ux. Time elapsed:  0.7037181854248047
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  0.8750476837158203
# ux 122471622
# apply secondary slice select array. Time elapsed:  0.13559341430664062
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.00471654166321662
# calculate particle level select array. Time elapsed:  0.02645277976989746
# apply particle level select array. Time elapsed:  0.0016903877258300781
# selected data length:  2344
# Total Time elapsed:  5.925878524780273

# %% [markdown]
# {'uz': [0.004700587593000333, 0.004798306273075093]}
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00010037422180175781
# The size of the query result:  3
# Direct block read. generate select array. Time elapsed:  7.62939453125e-06
# size of self.read_chunk_range:  3
# read data from disk: ux
# get target data: ux. Time elapsed:  3.02054762840271
# get mass read for ux. Time elapsed:  1.4937694072723389
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8770420551300049
# ux 260076280
# size of self.read_chunk_range:  3
# read data from disk: uz
# get target data: uz. Time elapsed:  2.473071336746216
# get mass read for uz. Time elapsed:  1.4954166412353516
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8638267517089844
# uz 260076280
# apply secondary slice select array. Time elapsed:  1.9073486328125e-06
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.6946394443511963
# apply particle level select array. Time elapsed:  0.0685575008392334
# selected data length:  90246
# Total Time elapsed:  13.0829336643219
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00019860267639160156
# The size of the query result:  3
# Direct block read. generate select array. Time elapsed:  0.1387040615081787
# size of self.read_chunk_range:  3
# read data from disk: ux
# get target data: ux. Time elapsed:  2.5570597648620605
# get mass read for ux. Time elapsed:  1.5022685527801514
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8534717559814453
# ux 260076280
# size of self.read_chunk_range:  3
# read data from disk: uz
# get target data: uz. Time elapsed:  2.428506851196289
# get mass read for uz. Time elapsed:  1.4936411380767822
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8561766147613525
# uz 260076280
# apply secondary slice select array. Time elapsed:  0.41095852851867676
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.10747265815734863
# apply particle level select array. Time elapsed:  0.009382009506225586
# selected data length:  90246
# Total Time elapsed:  12.395915031433105
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00020885467529296875
# The size of the query result:  3
# sort block metadata by block start. Time elapsed:  2.3603439331054688e-05
# find optimal read solution. Time elapsed:  2.3365020751953125e-05
# generate select array. Time elapsed:  0.22545218467712402
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  2.494248628616333
# get mass read for ux. Time elapsed:  1.4940745830535889
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8519203662872314
# ux 260076280
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  2.3756422996520996
# get mass read for uz. Time elapsed:  1.4978992938995361
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.855456829071045
# uz 260076280
# apply secondary slice select array. Time elapsed:  1.8637447357177734
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.6919655799865723
# apply particle level select array. Time elapsed:  0.07251095771789551
# selected data length:  90246
# Total Time elapsed:  14.520779609680176
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.0001990795135498047
# The size of the query result:  3
# sort block metadata by block start. Time elapsed:  1.6927719116210938e-05
# find optimal read solution. Time elapsed:  1.7642974853515625e-05
# generate select array. Time elapsed:  0.13819265365600586
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  2.400749444961548
# get mass read for ux. Time elapsed:  1.4982614517211914
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.855720043182373
# ux 260076280
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  2.465193510055542
# get mass read for uz. Time elapsed:  1.4947144985198975
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8573024272918701
# uz 260076280
# apply secondary slice select array. Time elapsed:  0.4168384075164795
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.10766839981079102
# apply particle level select array. Time elapsed:  0.009607315063476562
# selected data length:  90246
# Total Time elapsed:  12.28262448310852
# 90246

# %% [markdown]
# ### 1m for secondary slice

# %% [markdown]
# {'uz': [0.004700587593000333, 0.004798306273075093]}
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.0001285076141357422
# The size of the query result:  3
# Direct block read. generate select array. Time elapsed:  7.867813110351562e-06
# size of self.read_chunk_range:  3
# read data from disk: ux
# get target data: ux. Time elapsed:  3.054387092590332
# get mass read for ux. Time elapsed:  1.5149083137512207
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.9001190662384033
# ux 260076280
# size of self.read_chunk_range:  3
# read data from disk: uz
# get target data: uz. Time elapsed:  2.4998855590820312
# get mass read for uz. Time elapsed:  1.5134692192077637
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8894908428192139
# uz 260076280
# apply secondary slice select array. Time elapsed:  2.1457672119140625e-06
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.7056281566619873
# apply particle level select array. Time elapsed:  0.07121467590332031
# selected data length:  90246
# Total Time elapsed:  13.247244834899902
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00022268295288085938
# The size of the query result:  3
# Direct block read. generate select array. Time elapsed:  0.12347912788391113
# size of self.read_chunk_range:  3
# read data from disk: ux
# get target data: ux. Time elapsed:  2.6502082347869873
# get mass read for ux. Time elapsed:  1.5180127620697021
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8756377696990967
# ux 260076280
# size of self.read_chunk_range:  3
# read data from disk: uz
# get target data: uz. Time elapsed:  2.4054222106933594
# get mass read for uz. Time elapsed:  1.5139994621276855
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.87947416305542
# uz 260076280
# apply secondary slice select array. Time elapsed:  0.18387603759765625
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.013802289962768555
# apply particle level select array. Time elapsed:  0.0011031627655029297
# selected data length:  90246
# Total Time elapsed:  12.193698167800903
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.0002574920654296875
# The size of the query result:  3
# sort block metadata by block start. Time elapsed:  1.9788742065429688e-05
# find optimal read solution. Time elapsed:  2.1457672119140625e-05
# generate select array. Time elapsed:  0.22794818878173828
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  2.5273804664611816
# get mass read for ux. Time elapsed:  1.5148968696594238
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8725287914276123
# ux 260076280
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  2.301300525665283
# get mass read for uz. Time elapsed:  1.5127418041229248
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8789541721343994
# uz 260076280
# apply secondary slice select array. Time elapsed:  1.898972988128662
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.7046616077423096
# apply particle level select array. Time elapsed:  0.06991100311279297
# selected data length:  90246
# Total Time elapsed:  14.609135389328003
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00018906593322753906
# The size of the query result:  3
# sort block metadata by block start. Time elapsed:  1.71661376953125e-05
# find optimal read solution. Time elapsed:  1.6689300537109375e-05
# generate select array. Time elapsed:  0.12249064445495605
# size of self.read_chunk_range:  2
# read data from disk: ux
# get target data: ux. Time elapsed:  2.5206258296966553
# get mass read for ux. Time elapsed:  1.5183370113372803
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.880713939666748
# ux 260076280
# size of self.read_chunk_range:  2
# read data from disk: uz
# get target data: uz. Time elapsed:  2.4927968978881836
# get mass read for uz. Time elapsed:  1.5135576725006104
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8741028308868408
# uz 260076280
# apply secondary slice select array. Time elapsed:  0.17859578132629395
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.011075735092163086
# apply particle level select array. Time elapsed:  0.0015838146209716797
# selected data length:  90246
# Total Time elapsed:  12.142365455627441
# 90246

# %% [markdown]
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.0002651214599609375
# The size of the query result:  3
# Direct block read. generate select array. Time elapsed:  0.12311840057373047
# size of self.read_chunk_range:  3
# read data from disk: uz
# get target data: uz. Time elapsed:  2.4522182941436768
# get mass read for uz. Time elapsed:  1.492400884628296
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.8457262516021729
# uz 260076280
# size of self.read_chunk_range:  3
# read data from disk: ux
# get target data: ux. Time elapsed:  2.3580002784729004
# get mass read for ux. Time elapsed:  1.4800081253051758
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  1.840472936630249
# ux 260076280
# apply secondary slice select array. Time elapsed:  0.19143939018249512
# The lower bound of uz is 0.004700587593000333
# The upper bound of uz is 0.004798306273075093
# calculate particle level select array. Time elapsed:  0.01427769660949707
# apply particle level select array. Time elapsed:  0.0014064311981201172
# selected data length:  90246
# Total Time elapsed:  11.828778982162476
# 90246

# %% [markdown]
# {'uz': [0, 0.005898306273075093]}
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00025200843811035156
# The size of the query result:  12
# Direct block read. generate select array. Time elapsed:  1.71661376953125e-05
# size of self.read_chunk_range:  12
# read data from disk: uz
# get target data: uz. Time elapsed:  8.683080434799194
# get mass read for uz. Time elapsed:  5.2230446338653564
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.50033164024353
# uz 893342930
# apply secondary slice select array. Time elapsed:  4.0531158447265625e-06
# The lower bound of uz is 0
# The upper bound of uz is 0.005898306273075093
# calculate particle level select array. Time elapsed:  2.4089531898498535
# apply particle level select array. Time elapsed:  0.2901608943939209
# selected data length:  11424509
# Total Time elapsed:  23.378544092178345
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00036454200744628906
# The size of the query result:  12
# Direct block read. generate select array. Time elapsed:  0.4684469699859619
# size of self.read_chunk_range:  12
# read data from disk: uz
# get target data: uz. Time elapsed:  8.095699548721313
# get mass read for uz. Time elapsed:  5.212506294250488
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.487336874008179
# uz 893342930
# apply secondary slice select array. Time elapsed:  0.5513079166412354
# The lower bound of uz is 0
# The upper bound of uz is 0.005898306273075093
# calculate particle level select array. Time elapsed:  0.23631811141967773
# apply particle level select array. Time elapsed:  0.06328153610229492
# selected data length:  11424509
# Total Time elapsed:  21.182242393493652
# 11424509
#
# 10m secondary
#
# query index: Time elapsed:  0.000263214111328125
# The size of the query result:  12
# Direct block read. generate select array. Time elapsed:  0.5882425308227539
# size of self.read_chunk_range:  12
# read data from disk: uz
# get target data: uz. Time elapsed:  7.758083343505859
# get mass read for uz. Time elapsed:  5.113064527511597
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.424095392227173
# uz 893342930
# apply secondary slice select array. Time elapsed:  1.5442688465118408
# The lower bound of uz is 0
# The upper bound of uz is 0.005898306273075093
# calculate particle level select array. Time elapsed:  1.012615442276001
# apply particle level select array. Time elapsed:  0.14548921585083008
# selected data length:  11424509
# Total Time elapsed:  22.736034870147705
# 11424509

# %% [markdown]
# {'uz': [0.009498306273075094, 0.009899306273075094]}
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.00034880638122558594
# The size of the query result:  14
# Direct block read. generate select array. Time elapsed:  2.002716064453125e-05
# size of self.read_chunk_range:  14
# read data from disk: uz
# get target data: uz. Time elapsed:  8.9419527053833
# get mass read for uz. Time elapsed:  5.359838008880615
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.700900554656982
# uz 929172824
# apply secondary slice select array. Time elapsed:  2.86102294921875e-06
# The lower bound of uz is 0.009498306273075094
# The upper bound of uz is 0.009899306273075094
# calculate particle level select array. Time elapsed:  2.4742226600646973
# apply particle level select array. Time elapsed:  0.3077061176300049
# selected data length:  11290701
# Total Time elapsed:  24.062848567962646
# node min: 2.40925e-21, max: 2.46323e-19
# node min: 6.0511e-21, max: 7.97011e-21
# node min: 2.61889e-21, max: 2.45831e-19
# node min: 2.83409e-21, max: 2.2961e-19
# node min: 3.33045e-21, max: 1.9533e-19
# node min: 3.15776e-21, max: 2.44169e-19
# node min: 2.50469e-21, max: 2.36717e-19
# node min: 2.3673e-21, max: 2.39152e-19
# node min: 2.86486e-21, max: 2.46765e-19
# node min: 1.08604e-20, max: 1.91505e-19
# node min: 2.46532e-21, max: 2.45145e-19
# node min: 2.44486e-21, max: 2.40071e-19
# node min: 2.52562e-21, max: 2.40607e-19
# node min: 2.48381e-21, max: 2.46509e-19
# node min: 2.39706e-21, max: 2.40803e-19
# node min: 2.35706e-21, max: 2.44523e-19
# query index: Time elapsed:  0.0004913806915283203
# The size of the query result:  14
# Direct block read. generate select array. Time elapsed:  0.6015396118164062
# size of self.read_chunk_range:  14
# read data from disk: uz
# get target data: uz. Time elapsed:  8.366373777389526
# get mass read for uz. Time elapsed:  5.349096298217773
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.6862101554870605
# uz 929172824
# apply secondary slice select array. Time elapsed:  1.5918231010437012
# The lower bound of uz is 0.009498306273075094
# The upper bound of uz is 0.009899306273075094
# calculate particle level select array. Time elapsed:  1.054823637008667
# apply particle level select array. Time elapsed:  0.15840601921081543
# selected data length:  11290701
# Total Time elapsed:  23.954622507095337
# 11290701
#
# query index: Time elapsed:  0.0002696514129638672
# The size of the query result:  14
# Direct block read. generate select array. Time elapsed:  0.7631180286407471
# size of self.read_chunk_range:  14
# read data from disk: uz
# get target data: uz. Time elapsed:  8.360172510147095
# get mass read for uz. Time elapsed:  5.331475496292114
# mass: [1.67262e-27 1.67262e-27 1.67262e-27 ... 1.67262e-27 1.67262e-27
#  1.67262e-27]
# data *= norm_factor. Time elapsed:  6.668004512786865
# uz 929172824
# apply secondary slice select array. Time elapsed:  3.014469623565674
# The lower bound of uz is 0.009498306273075094
# The upper bound of uz is 0.009899306273075094
# calculate particle level select array. Time elapsed:  2.1665167808532715
# apply particle level select array. Time elapsed:  0.2720019817352295
# selected data length:  11290701
# Total Time elapsed:  26.832309246063232
# 11290701

# %%
global_tick_fontsize = 20
global_label_fontsize = 24
global_annotation_fontsize = 20
global_legend_fontsize = 18

# %%
import matplotlib
# matplotlib.use('pgf')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import MaxNLocator, MultipleLocator

import warnings
warnings.filterwarnings('ignore')

plt.rcParams["font.family"] = "serif"
plt.rcParams["font.serif"] = ["Times New Roman"]

# %%
proj_path = "/data/gc_openPMD-viewer/"

df_path = proj_path + "results/final/middle_secondary.csv"
# df_path = "/data/gc/rocksdb-index/openPMD-viewer/results/final/large.csv"
df = pd.read_csv(df_path, header=[0])

# %%
# df = df[df['target_particle_number'].isin([90246, 11224509, 11290701])]
df = df[df['target_particle_number'].isin([90246, 11224509, 1062818])]
df['index_cost'] = df['query index'] + df['generate select array'] + df['apply secondary slice select array']
df['calculation_cost'] = df['calculate particle level select array'] + df['apply particle level select array']
df['total_cost'] = df['index_cost'] + df['calculation_cost']
df['group_label'] = df['use secondary'].astype(str) + df['secondary size'].astype(str)

# %%
df
# Out:
#     target_particle_number  use secondary secondary size  query index  \
# 4                    90246          False             1k     0.000100
# 5                    90246           True            10m     0.000199
# 6                    90246           True             1k     0.000265
# 7                    90246           True             1n     0.294968
# 8                 11224509          False             1k     0.000252
# 9                 11224509           True             1k     0.000365
# 10                11224509           True            10m     0.000263
# 11                11224509           True             1n     1.018768
# 15                 1062818          False             1k     0.000178
# 16                 1062818           True             1k     0.000320
# 17                 1062818           True            10m     0.000291
# 18                 1062818           True             1n     0.747488
#
# ...

# %%
df.columns
# Out:
# Index(['target_particle_number', 'use secondary', 'secondary size',
#        'query index', 'generate select array',
#        'apply secondary slice select array',
#        'calculate particle level select array',
#        'apply particle level select array', 'touched_cells', 'dimension',
#        'index_cost', 'calculation_cost', 'total_cost', 'group_label'],
#       dtype='object')

# %%
print(df)
# Out:
#     target_particle_number  use secondary secondary size  query index  \
# 4                    90246          False             1k     0.000100
# 5                    90246           True            10m     0.000199
# 6                    90246           True             1k     0.000265
# 7                    90246           True             1n     0.294968
# 8                 11224509          False             1k     0.000252
# 9                 11224509           True             1k     0.000365
# 10                11224509           True            10m     0.000263
# 11                11224509           True             1n     1.018768
# 15                 1062818          False             1k     0.000178
# 16                 1062818           True             1k     0.000320
# 17                 1062818           True            10m     0.000291
# 18                 1062818           True             1n     0.747488
#
# ...

# %%
# Group by 'target_particle_number' and 'group_label' and sum the costs
grouped_costs = df.groupby(['target_particle_number', 'group_label'])[['index_cost', 'calculation_cost']].sum().reset_index()

# Create a new DataFrame for plotting
plot_data = pd.DataFrame()

# For each group, prepare the data for plotting
for group in grouped_costs['group_label'].unique():
    group_data = grouped_costs[grouped_costs['group_label'] == group].copy()
    group_data.set_index('target_particle_number', inplace=True)
    plot_data[group] = group_data['index_cost'] + group_data['calculation_cost']  # Total cost as a demonstration

# desired_order = [11424509, 11290701]
# plot_data = plot_data.loc[desired_order]
# plot_data = plot_data[::-1]
# Reset index for plotting
plot_data = plot_data.reset_index()

# Plotting
fig, ax = plt.subplots(figsize=(6, 4.5))

# Plot for index_cost
bar_width = 0.25
plt.ylim(0, 6.9999)
x = range(len(plot_data['target_particle_number']))

patterns = {
    'index_cost': '/',
    'calculation_cost': '.'
}

# Plotting each group as separate bars
for i, group in enumerate(grouped_costs['group_label'].unique()):
    index_cost_values = grouped_costs[grouped_costs['group_label'] == group]['index_cost']
    calculation_cost_values = grouped_costs[grouped_costs['group_label'] == group]['calculation_cost']

    ax.bar(
        [p + (i * bar_width) for p in x],
        index_cost_values,
        width=bar_width,
        label=f'{group}',
        color='#bdbdbd' if group == 'False1k' else ('#9ecae1' if group == 'True1k' else '#74c476'),
        hatch=patterns['index_cost'],
        bottom=calculation_cost_values  # Bottom is zero for the first group
    )

    ax.bar(
        [p + (i * bar_width) for p in x],
        calculation_cost_values,
        width=bar_width,
        # label=f'{group}',
        color='#bdbdbd' if group == 'False1k' else ('#6baed6' if group == 'True1k' else '#66c2a4'),
        hatch=patterns['calculation_cost'],
        bottom=[0]*len(calculation_cost_values)  # Stack on top of index cost
    )




from matplotlib import pyplot
legend = pyplot.legend(title='', loc='upper center', labels=['Cell', '', 'In-Cell 10M', '', 'In-Cell 1K', ""], fontsize=global_legend_fontsize - 3, ncol=3, frameon=False, bbox_to_anchor=(0.48, 1.13)) # Move legend above the figure)


for i, text in enumerate(legend.get_texts()):
    text.set_fontweight('bold')
    text.set_ha('right')
    if text.get_text() == '':  # Or any other condition to identify unwanted entries
        legend.legend_handles[i].set_visible(False)  # Hide the handle
        text.set_visible(False)  # Hide the text

print(ax.patches[0])
for i, p in enumerate(ax.patches):
    if i in [0, 1, 2, 6, 7, 8, 12, 13, 14]:
        continue
    else:
        if i in [3, 4, 5]:
            ax.annotate(format(p.get_height() + ax.patches[i - 3].get_height(), '.2f'), (p.get_x() - 0.07, p.get_height()  + ax.patches[i - 3].get_height() + 0.1), fontsize=global_annotation_fontsize, fontweight='bold')
        elif i in [9, 10, 11]:
            ax.annotate(format(p.get_height() + ax.patches[i - 3].get_height(), '.2f'), (p.get_x(), p.get_height()  + ax.patches[i - 3].get_height() + 0.1), fontsize=global_annotation_fontsize, fontweight='bold')
        else:
            ax.annotate(format(p.get_height() + ax.patches[i - 3].get_height(), '.2f'), (p.get_x() + 0.02, p.get_height()  + ax.patches[i - 3].get_height() + 0.1), fontsize=global_annotation_fontsize, fontweight='bold')

    # ax.annotate(i, (p.get_x(), p.get_height()), fontsize=global_annotation_fontsize, fontweight='bold')
    # if i % 2 != 0:
    #     continue
    # else:
    #     ax.annotate(format(round(p.get_height() + ax.patches[i + 1].get_height(), 2), '.2f'), (p.get_x() - 0.20, p.get_height() + 0.04), fontsize=global_annotation_fontsize - 5, fontweight='bold')

current_values = plt.gca().get_yticks()
# plt.gca().yaxis.set_major_formatter(FuncFormatter(exp_formatter))
# plt.gca().yaxis.set_major_locator(MaxNLocator(nbins=3))
plt.gca().set_yticklabels([str(int(y * 2)) for y in plt.gca().get_yticks()])

# Adjust tick label fontsize
plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize - 3, pad=3)

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

from matplotlib.patches import Patch

# Create custom legend handles for the hatch patterns
hatch_legend = [
    Patch(facecolor='white', edgecolor='black', hatch='/', label='Index Cost'),
    Patch(facecolor='white', edgecolor='black', hatch='.', label='Filter Cost')
]
ax2 = ax.twinx()
ax2.get_yaxis().set_visible(False)
# Add the custom hatch legend to the figure
legend2 = ax2.legend(handles=hatch_legend, title='', loc='upper left', fontsize=global_legend_fontsize - 3)
# # Draw both legends
#

for i, text in enumerate(legend2.get_texts()):
    text.set_fontweight('bold')
# pyplot.gca().add_artist(legend)  # Add the first legend
# pyplot.gca().add_artist(legend2)  # Add the second legend

# Add labels and title
ax.set_ylabel('Time (seconds)', fontsize=global_label_fontsize, fontweight='bold')
ax.set_xlabel('Select Percentage, Query Locality', fontsize=global_label_fontsize, fontweight='bold')
# ax.set_title('Stacked Bar Plot of Costs by Target Particle Number and Group')
ax.set_xticks([p + bar_width for p in x])  # Set x-ticks in the middle of the bars
ax.set_xticklabels(["0.01%, Left", "1%, Left", "1%, Middle"], rotation=0)  # Set labels to the x-ticks
# ax.legend(title='')

plt.tight_layout()
plt.savefig(proj_path + "plot/final/secondary_middle.svg", bbox_inches='tight', pad_inches=0.1)

plt.show()
# Out:
# Rectangle(xy=(-0.125, 0.763197), width=0.25, height=0.000109911, angle=0)

# %%
# only keep the columns of ['target_particle_number', 'group_label', 'total_cost']
df = df[['target_particle_number', 'group_label', 'total_cost', 'touched_cells', 'dimension', 'index_cost', 'calculation_cost']]
df
# Out:
#     target_particle_number group_label  total_cost  touched_cells  dimension  \
# 4                    90246     False1k    0.763307              3          1
# 5                    90246     True10m    0.666716              3          1
# 6                    90246      True1k    0.330507              3          1
# 7                    90246      True1n    0.504162              3          1
# 8                 11224509     False1k    2.699387             12          3
# 9                 11224509      True1k    1.319719             12          3
# 10                11224509     True10m    3.290879             12          3
# 11                11224509      True1n    2.092577             12          3
# 15                 1062818     False1k    2.014672              9          2
# 16                 1062818      True1k    0.693919              9          2
# 17                 1062818     True10m    1.598917              9          2
# ...

# %%
legend_labels = ['One-Tier', 'Two-Tier Small', 'Two-Tier Median', 'Two-Tier Large']

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 5)

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='total_cost').plot(kind='bar',ax=ax, width=0.85, color=['#bdbdbd', '#74c476', '#6baed6', '#9e9ac8'])


# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['One-Tier', 'Two-Tier S', 'In-Cell M', 'In-Cell L']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.08, 1.28), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.02, 1.28), columnspacing=3)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.04, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 6 and i < 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.01, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x(), p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 3.8)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Time Elapsed (s)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

'''
ax2 = ax.twinx()
# ax2.set_xlim((ax.get_xlim()))
# with point * as marker
# select_set_length is the x-axis and start from 0
plot_df['dimension'] = plot_df['dimension'] - 1
plot_df[plot_df['group_label']=='True1k'].pivot(index='dimension', columns='group_label', values='touched_cells').plot(kind='line', ax=ax2, color='red', marker='*', markersize=10, linewidth=3)

plt.ylabel("Avg Touched Cells", fontsize=global_label_fontsize, rotation=270, labelpad=25, fontweight='bold')
current_values = plt.gca().get_yticks()
plt.gca().yaxis.set_major_locator(MultipleLocator(5))
# plt.gca().yaxis.set_major_formatter(FuncFormatter(exp_formatter))
# plt.gca().set_yticklabels([f"{int(y / 1000)}k" if y != 0 else "0" for y in plt.gca().get_yticks()])
plt.ylim(0, 15.8)
# Adjust tick label fontsize
plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize)  # Adjust label size as needed

# Remove the legend
plt.gca().get_legend().remove()
plt.yticks(fontweight='bold')
'''
# Set up the bar chart
# pivot_df.plot(kind='bar', figsize=(10, 6))

# Add labels and title
# plt.xlabel('Group')
# plt.ylabel('Value')
# plt.title('Bar Plot of Values for Different Labels by Group')

ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 4.4)

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='total_cost').plot(kind='bar',ax=ax, width=0.85, color=['#bdbdbd', '#74c476', '#6baed6', '#9e9ac8'])


# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['One-Tier', 'Two-Tier S', 'In-Cell M', 'In-Cell L']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.07, 1.38), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.02, 1.28), columnspacing=3)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.04, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 6 and i < 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.01, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x(), p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 3.89)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Time Elapsed (s)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

'''
ax2 = ax.twinx()
# ax2.set_xlim((ax.get_xlim()))
# with point * as marker
# select_set_length is the x-axis and start from 0
plot_df['dimension'] = plot_df['dimension'] - 1
plot_df[plot_df['group_label']=='True1k'].pivot(index='dimension', columns='group_label', values='touched_cells').plot(kind='line', ax=ax2, color='red', marker='*', markersize=10, linewidth=3)

plt.ylabel("Avg Touched Cells", fontsize=global_label_fontsize, rotation=270, labelpad=25, fontweight='bold')
current_values = plt.gca().get_yticks()
plt.gca().yaxis.set_major_locator(MultipleLocator(5))
# plt.gca().yaxis.set_major_formatter(FuncFormatter(exp_formatter))
# plt.gca().set_yticklabels([f"{int(y / 1000)}k" if y != 0 else "0" for y in plt.gca().get_yticks()])
plt.ylim(0, 15.8)
# Adjust tick label fontsize
plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize)  # Adjust label size as needed

# Remove the legend
plt.gca().get_legend().remove()
plt.yticks(fontweight='bold')
'''
# Set up the bar chart
# pivot_df.plot(kind='bar', figsize=(10, 6))

# Add labels and title
# plt.xlabel('Group')
# plt.ylabel('Value')
# plt.title('Bar Plot of Values for Different Labels by Group')

ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index_v2.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 4.4)

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='total_cost').plot(kind='bar',ax=ax, width=0.85, color=['#fbb4ae', '#b3cde3', '#ccebc5', '#decbe4'])


# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['One-Tier', 'Two-Tier S', 'In-Cell M', 'In-Cell L']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.07, 1.38), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.02, 1.28), columnspacing=3)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.04, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 6 and i < 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.01, p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x(), p.get_height() + 0.05), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 3.89)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Time Elapsed (s)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

'''
ax2 = ax.twinx()
# ax2.set_xlim((ax.get_xlim()))
# with point * as marker
# select_set_length is the x-axis and start from 0
plot_df['dimension'] = plot_df['dimension'] - 1
plot_df[plot_df['group_label']=='True1k'].pivot(index='dimension', columns='group_label', values='touched_cells').plot(kind='line', ax=ax2, color='red', marker='*', markersize=10, linewidth=3)

plt.ylabel("Avg Touched Cells", fontsize=global_label_fontsize, rotation=270, labelpad=25, fontweight='bold')
current_values = plt.gca().get_yticks()
plt.gca().yaxis.set_major_locator(MultipleLocator(5))
# plt.gca().yaxis.set_major_formatter(FuncFormatter(exp_formatter))
# plt.gca().set_yticklabels([f"{int(y / 1000)}k" if y != 0 else "0" for y in plt.gca().get_yticks()])
plt.ylim(0, 15.8)
# Adjust tick label fontsize
plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize)  # Adjust label size as needed

# Remove the legend
plt.gca().get_legend().remove()
plt.yticks(fontweight='bold')
'''
# Set up the bar chart
# pivot_df.plot(kind='bar', figsize=(10, 6))

# Add labels and title
# plt.xlabel('Group')
# plt.ylabel('Value')
# plt.title('Bar Plot of Values for Different Labels by Group')

ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index_v3.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
plot_df['index_cost_percentage'] = plot_df['index_cost'] / plot_df['total_cost']
plot_df['calculation_cost_percentage'] = plot_df['calculation_cost'] / plot_df['total_cost']
plot_df
# Out:
#     target_particle_number group_label  total_cost  touched_cells  dimension  \
# 4                    90246     False1k    0.763307              3          1
# 5                    90246     True10m    0.666716              3          1
# 6                    90246      True1k    0.330507              3          1
# 7                    90246      True1n    0.504162              3          1
# 8                 11224509     False1k    2.699387             12          3
# 9                 11224509      True1k    1.319719             12          3
# 10                11224509     True10m    3.290879             12          3
# 11                11224509      True1n    2.092577             12          3
# 15                 1062818     False1k    2.014672              9          2
# 16                 1062818      True1k    0.693919              9          2
# 17                 1062818     True10m    1.598917              9          2
# ...

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 5)

plot_df['index_cost_percentage'] = plot_df['index_cost'] / plot_df['total_cost']
plot_df['calculation_cost_percentage'] = plot_df['calculation_cost'] / plot_df['total_cost']
plot_df['index_cost_percentage'] = plot_df['index_cost_percentage'] * 100

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='index_cost_percentage').plot(kind='bar',ax=ax, width=0.85, color=['#bdbdbd', '#74c476', '#6baed6', '#9e9ac8'])

# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['Cell Only', 'In-Cell L', 'In-Cell M', 'In-Cell S']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.11, 1.28), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(0.05, 1.28), columnspacing=0.8)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(int(p.get_height())), (p.get_x(), p.get_height() + 2), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() + 0.02, p.get_height() + 2.4), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.14, p.get_height() + 1.4), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 119)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Index Cost (%)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')

'''
ax2 = ax.twinx()
# ax2.set_xlim((ax.get_xlim()))
# with point * as marker
# select_set_length is the x-axis and start from 0
plot_df['dimension'] = plot_df['dimension'] - 1
plot_df[plot_df['group_label']=='True1k'].pivot(index='dimension', columns='group_label', values='touched_cells').plot(kind='line', ax=ax2, color='red', marker='*', markersize=10, linewidth=3)

plt.ylabel("Avg Touched Cells", fontsize=global_label_fontsize, rotation=270, labelpad=25, fontweight='bold')
current_values = plt.gca().get_yticks()
plt.gca().yaxis.set_major_locator(MultipleLocator(5))
# plt.gca().yaxis.set_major_formatter(FuncFormatter(exp_formatter))
# plt.gca().set_yticklabels([f"{int(y / 1000)}k" if y != 0 else "0" for y in plt.gca().get_yticks()])
plt.ylim(0, 15.8)
# Adjust tick label fontsize
plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize)  # Adjust label size as needed

# Remove the legend
plt.gca().get_legend().remove()
plt.yticks(fontweight='bold')
'''
# Set up the bar chart
# pivot_df.plot(kind='bar', figsize=(10, 6))

# Add labels and title
# plt.xlabel('Group')
# plt.ylabel('Value')
# plt.title('Bar Plot of Values for Different Labels by Group')

ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index_percent.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 4.4)

plot_df['index_cost_percentage'] = plot_df['index_cost'] / plot_df['total_cost']
plot_df['calculation_cost_percentage'] = plot_df['calculation_cost'] / plot_df['total_cost']
plot_df['index_cost_percentage'] = plot_df['index_cost_percentage'] * 100

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='index_cost_percentage').plot(kind='bar',ax=ax, width=0.85, color=['#bdbdbd', '#74c476', '#6baed6', '#9e9ac8'])

# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['Cell Only', 'In-Cell L', 'In-Cell M', 'In-Cell S']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.11, 1.38), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(0.05, 1.28), columnspacing=0.8)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(int(p.get_height())), (p.get_x(), p.get_height() + 2), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() + 0.0, p.get_height() + 2.4), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.14, p.get_height() + 1.4), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 119)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Index Cost (%)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')



ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index_percent_v2.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()

# %%
import copy
plot_df = copy.deepcopy(df)

fig, ax = plt.subplots()
# set figure size
fig.set_size_inches(6, 4.4)

plot_df['index_cost_percentage'] = plot_df['index_cost'] / plot_df['total_cost']
plot_df['calculation_cost_percentage'] = plot_df['calculation_cost'] / plot_df['total_cost']
plot_df['index_cost_percentage'] = plot_df['index_cost_percentage'] * 100

# Pivot the data for plotting
plot_df.pivot(index='dimension', columns='group_label', values='index_cost_percentage').plot(kind='bar',ax=ax, width=0.85, color=['#fbb4ae', '#b3cde3', '#ccebc5', '#decbe4'])

# Get the existing legend handles and labels
handles, labels = plt.gca().get_legend_handles_labels()
# labels=['Cell Only', 'In-Cell L', 'In-Cell M', 'In-Cell S']
# Reorder handles and labels for row-wise layout
new_order = [0, 2, 1, 3]  # Change order from column-wise to row-wise
handles = [handles[i] for i in new_order]
new_legend_labels = [legend_labels[i] for i in new_order]
# legend = plt.legend(handles, labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=4, frameon=False, bbox_to_anchor=(-0.0, 1.28), columnspacing=1)
legend = plt.legend(handles, new_legend_labels, title='', loc='upper left', fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(-0.11, 1.38), columnspacing=0.9, handletextpad=0.3)
# legend = ax.legend(title='', loc='upper left', labels=['Cell Only', 'In-Cell 10M', 'In-Cell 1M', 'In-Cell 100'], fontsize=global_legend_fontsize, ncol=2, frameon=False, bbox_to_anchor=(0.05, 1.28), columnspacing=0.8)

for text in legend.get_texts():
    text.set_fontweight('bold')

for i, p in enumerate(ax.patches):
    if i < 3:
        ax.annotate(str(int(p.get_height())), (p.get_x(), p.get_height() + 2), fontsize=global_annotation_fontsize, fontweight='bold')
    elif i >= 9:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() + 0.0, p.get_height() + 2.4), fontsize=global_annotation_fontsize, fontweight='bold')
    else:
        ax.annotate(str(round(p.get_height(), 1)), (p.get_x() - 0.14, p.get_height() + 1.4), fontsize=global_annotation_fontsize, fontweight='bold')

plt.ylim(0, 119)


plt.xlabel("Different Select Proportions", fontsize=global_label_fontsize - 2, fontweight='bold')
# y label
plt.ylabel("Avg Index Cost (%)", fontsize=global_label_fontsize, fontweight='bold')


plt.gca().tick_params(axis='y', labelsize=global_tick_fontsize, pad=2)  # Adjust label size as needed
plt.gca().tick_params(axis='x', labelsize=global_tick_fontsize)  # Adjust label size as needed

plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')



ax.set_xticks(np.arange(3))
custom_labels = ['0.01%', '0.1%', '1%']
ax.set_xticklabels(custom_labels, rotation=0)
# plt.xticks(rotation=90)  # Keep group labels horizontal

# Show plot
plt.tight_layout()
plt.savefig(proj_path + "plot/final/multi_level_index_percent_v3.pdf", bbox_inches='tight', pad_inches=0.01)
plt.show()
